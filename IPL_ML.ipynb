# %%
import pandas as pd
import numpy as np
import random as rnd

# for data visualization 
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_ball=pd.read_csv("D:/Prateek/Project_Data/IPL_project/IPL Ball-by-Ball 2008-2020.csv")
df_ball
# Out:
#              id  inning  over  ball      batsman  non_striker  \
# 0        335982       1     6     5   RT Ponting  BB McCullum
# 1        335982       1     6     6  BB McCullum   RT Ponting
# 2        335982       1     7     1  BB McCullum   RT Ponting
# 3        335982       1     7     2  BB McCullum   RT Ponting
# 4        335982       1     7     3   RT Ponting  BB McCullum
# ...         ...     ...   ...   ...          ...          ...
# 193463  1237181       1    12     5      RR Pant      SS Iyer
# 193464  1237181       1    12     6      RR Pant      SS Iyer
# 193465  1237181       1    13     1      RR Pant      SS Iyer
# 193466  1237181       1    13     2      RR Pant      SS Iyer
# 193467  1237181       1    13     3      SS Iyer      RR Pant
#
#                  bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 0             AA Noffke             1           0           1             0
# ...

# %%
df_match=pd.read_csv("D:/Prateek/Project_Data/IPL_project/IPL Matches 2008-2020.csv")
df_match
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  18-04-2008     BB McCullum
# 1     335983  Chandigarh  19-04-2008      MEK Hussey
# 2     335984       Delhi  19-04-2008     MF Maharoof
# 3     335985      Mumbai  20-04-2008      MV Boucher
# 4     335986     Kolkata  20-04-2008       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  28-09-2020  AB de Villiers
# 812  1237177       Dubai  05-11-2020       JJ Bumrah
# 813  1237178   Abu Dhabi  06-11-2020   KS Williamson
# 814  1237180   Abu Dhabi  08-11-2020      MP Stoinis
# 815  1237181       Dubai  10-11-2020        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df_match.head(10)
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  18-04-2008     BB McCullum
# 1  335983  Chandigarh  19-04-2008      MEK Hussey
# 2  335984       Delhi  19-04-2008     MF Maharoof
# 3  335985      Mumbai  20-04-2008      MV Boucher
# 4  335986     Kolkata  20-04-2008       DJ Hussey
# 5  335987      Jaipur  21-04-2008       SR Watson
# 6  335988   Hyderabad  22-04-2008        V Sehwag
# 7  335989     Chennai  23-04-2008       ML Hayden
# 8  335990   Hyderabad  24-04-2008       YK Pathan
# 9  335991  Chandigarh  25-04-2008   KC Sangakkara
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
# ...

# %%
df_match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df_match.describe()
# Out:
#                  id  neutral_venue  result_margin
# count  8.160000e+02     816.000000     799.000000
# mean   7.563496e+05       0.094363      17.321652
# std    3.058943e+05       0.292512      22.068427
# min    3.359820e+05       0.000000       1.000000
# 25%    5.012278e+05       0.000000       6.000000
# 50%    7.292980e+05       0.000000       8.000000
# 75%    1.082626e+06       0.000000      19.500000
# max    1.237181e+06       1.000000     146.000000

# %%
df_match.isnull().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
match=df_match[["id","city","winner",]]

# %%
match
# Out:
#           id        city                       winner
# 0     335982   Bangalore        Kolkata Knight Riders
# 1     335983  Chandigarh          Chennai Super Kings
# 2     335984       Delhi             Delhi Daredevils
# 3     335985      Mumbai  Royal Challengers Bangalore
# 4     335986     Kolkata        Kolkata Knight Riders
# ..       ...         ...                          ...
# 811  1216547       Dubai  Royal Challengers Bangalore
# 812  1237177       Dubai               Mumbai Indians
# 813  1237178   Abu Dhabi          Sunrisers Hyderabad
# 814  1237180   Abu Dhabi               Delhi Capitals
# 815  1237181       Dubai               Mumbai Indians
#
# [816 rows x 3 columns]

# %%
match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      816 non-null    int64
#  1   city    803 non-null    object
#  2   winner  812 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 19.2+ KB

# %%
df_ball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193468 entries, 0 to 193467
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                193468 non-null  int64
#  1   inning            193468 non-null  int64
#  2   over              193468 non-null  int64
#  3   ball              193468 non-null  int64
#  4   batsman           193468 non-null  object
#  5   non_striker       193468 non-null  object
#  6   bowler            193468 non-null  object
#  7   batsman_runs      193468 non-null  int64
#  8   extra_runs        193468 non-null  int64
#  9   total_runs        193468 non-null  int64
#  10  non_boundary      193468 non-null  int64
#  11  is_wicket         193468 non-null  int64
#  12  dismissal_kind    9495 non-null    object
#  13  player_dismissed  9495 non-null    object
#  14  fielder           6784 non-null    object
#  15  extras_type       10233 non-null   object
# ...

# %%
df_ball.isnull().sum()
# Out:
# id                       0
# inning                   0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# non_boundary             0
# is_wicket                0
# dismissal_kind      183973
# player_dismissed    183973
# fielder             186684
# extras_type         183235
# batting_team             0
# bowling_team           191
# dtype: int64

# %%
ball=df_ball[["id","inning","over","ball","batsman_runs","total_runs","is_wicket","batting_team","bowling_team"]]

# %%
ball
# Out:
#              id  inning  over  ball  batsman_runs  total_runs  is_wicket  \
# 0        335982       1     6     5             1           1          0
# 1        335982       1     6     6             1           1          0
# 2        335982       1     7     1             0           0          0
# 3        335982       1     7     2             1           1          0
# 4        335982       1     7     3             1           1          0
# ...         ...     ...   ...   ...           ...         ...        ...
# 193463  1237181       1    12     5             0           0          0
# 193464  1237181       1    12     6             1           1          0
# 193465  1237181       1    13     1             0           1          0
# 193466  1237181       1    13     2             1           1          0
# 193467  1237181       1    13     3             1           1          0
#
#                  batting_team                 bowling_team
# ...

# %%
ball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193468 entries, 0 to 193467
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            193468 non-null  int64
#  1   inning        193468 non-null  int64
#  2   over          193468 non-null  int64
#  3   ball          193468 non-null  int64
#  4   batsman_runs  193468 non-null  int64
#  5   total_runs    193468 non-null  int64
#  6   is_wicket     193468 non-null  int64
#  7   batting_team  193468 non-null  object
#  8   bowling_team  193277 non-null  object
# dtypes: int64(7), object(2)
# memory usage: 13.3+ MB

# %%
ball.isnull().sum()
# Out:
# id                0
# inning            0
# over              0
# ball              0
# batsman_runs      0
# total_runs        0
# is_wicket         0
# batting_team      0
# bowling_team    191
# dtype: int64

# %%
ball=ball.dropna()

# %%
ball.isnull().sum()
# Out:
# id              0
# inning          0
# over            0
# ball            0
# batsman_runs    0
# total_runs      0
# is_wicket       0
# batting_team    0
# bowling_team    0
# dtype: int64

# %%
ball
# Out:
#              id  inning  over  ball  batsman_runs  total_runs  is_wicket  \
# 0        335982       1     6     5             1           1          0
# 1        335982       1     6     6             1           1          0
# 2        335982       1     7     1             0           0          0
# 3        335982       1     7     2             1           1          0
# 4        335982       1     7     3             1           1          0
# ...         ...     ...   ...   ...           ...         ...        ...
# 193463  1237181       1    12     5             0           0          0
# 193464  1237181       1    12     6             1           1          0
# 193465  1237181       1    13     1             0           1          0
# 193466  1237181       1    13     2             1           1          0
# 193467  1237181       1    13     3             1           1          0
#
#                  batting_team                 bowling_team
# ...

# %%
r=ball.groupby(['id','inning']).sum()["total_runs"].reset_index()
r=r[r["inning"]==1]
r=r.drop(columns="inning")
r
# Out:
#            id  total_runs
# 0      335982         222
# 2      335983         240
# 4      335984         129
# 6      335985         165
# 8      335986         110
# ...       ...         ...
# 1618  1216547         201
# 1620  1237177         200
# 1622  1237178         131
# 1624  1237180         189
# 1626  1237181         156
#
# [814 rows x 2 columns]

# %%
ball=ball[ball["inning"]==2]
ball
# Out:
#              id  inning  over  ball  batsman_runs  total_runs  is_wicket  \
# 121      335982       2     6     2             0           0          0
# 122      335982       2     6     3             1           1          0
# 123      335982       2     6     4             0           1          0
# 124      335982       2     6     5             0           1          0
# 125      335982       2     6     6             0           0          0
# ...         ...     ...   ...   ...           ...         ...        ...
# 193372  1237181       2    17     6             1           1          0
# 193373  1237181       2    18     1             1           1          0
# 193374  1237181       2    18     2             1           1          0
# 193375  1237181       2    18     3             0           0          1
# 193376  1237181       2    18     4             1           1          0
#
#                        batting_team           bowling_team
# ...

# %%
ball=pd.merge(ball, r,how='right',on="id")

ball
# Out:
#             id  inning  over  ball  batsman_runs  total_runs_x  is_wicket  \
# 0       335982       2     6     2             0             0          0
# 1       335982       2     6     3             1             1          0
# 2       335982       2     6     4             0             1          0
# 3       335982       2     6     5             0             1          0
# 4       335982       2     6     6             0             0          0
# ...        ...     ...   ...   ...           ...           ...        ...
# 93272  1237181       2    17     6             1             1          0
# 93273  1237181       2    18     1             1             1          0
# 93274  1237181       2    18     2             1             1          0
# 93275  1237181       2    18     3             0             0          1
# 93276  1237181       2    18     4             1             1          0
#
#                       batting_team           bowling_team  total_runs_y
# ...

# %%
ball=ball.groupby(['id'], sort=False).apply(lambda x: x.sort_values(["over","ball"], ascending=True)).reset_index(drop=True)
ball
# Out:
#             id  inning  over  ball  batsman_runs  total_runs_x  is_wicket  \
# 0       335982       2     0     1             1             1          0
# 1       335982       2     0     2             0             1          0
# 2       335982       2     0     3             0             0          0
# 3       335982       2     0     4             1             1          0
# 4       335982       2     0     5             1             1          0
# ...        ...     ...   ...   ...           ...           ...        ...
# 93272  1237181       2    17     6             1             1          0
# 93273  1237181       2    18     1             1             1          0
# 93274  1237181       2    18     2             1             1          0
# 93275  1237181       2    18     3             0             0          1
# 93276  1237181       2    18     4             1             1          0
#
#                       batting_team           bowling_team  total_runs_y
# ...

# %%
ball["balls_left"]=120-(ball["over"]*6+ball["ball"])
ball
# Out:
#             id  inning  over  ball  batsman_runs  total_runs_x  is_wicket  \
# 0       335982       2     0     1             1             1          0
# 1       335982       2     0     2             0             1          0
# 2       335982       2     0     3             0             0          0
# 3       335982       2     0     4             1             1          0
# 4       335982       2     0     5             1             1          0
# ...        ...     ...   ...   ...           ...           ...        ...
# 93272  1237181       2    17     6             1             1          0
# 93273  1237181       2    18     1             1             1          0
# 93274  1237181       2    18     2             1             1          0
# 93275  1237181       2    18     3             0             0          1
# 93276  1237181       2    18     4             1             1          0
#
#                       batting_team           bowling_team  total_runs_y  \
# ...

# %%
runs=ball.groupby("id").cumsum()["total_runs_x"]
ball["current_runs"]=runs
ball
# Out:
#             id  inning  over  ball  batsman_runs  total_runs_x  is_wicket  \
# 0       335982       2     0     1             1             1          0
# 1       335982       2     0     2             0             1          0
# 2       335982       2     0     3             0             0          0
# 3       335982       2     0     4             1             1          0
# 4       335982       2     0     5             1             1          0
# ...        ...     ...   ...   ...           ...           ...        ...
# 93272  1237181       2    17     6             1             1          0
# 93273  1237181       2    18     1             1             1          0
# 93274  1237181       2    18     2             1             1          0
# 93275  1237181       2    18     3             0             0          1
# 93276  1237181       2    18     4             1             1          0
#
#                       batting_team           bowling_team  total_runs_y  \
# ...

# %%
wicket=ball.groupby("id").cumsum()["is_wicket"]
ball["wicket_left"]=10-wicket

# %%
runs=ball.groupby("id").cumsum()["total_runs_x"]
runs.shape
ball["runs"]=runs
ball["runs_left"]=ball["total_runs_y"]-runs+1

# %%
ball.head(20)
# Out:
#         id  inning  over  ball  batsman_runs  total_runs_x  is_wicket  \
# 0   335982       2     0     1             1             1          0
# 1   335982       2     0     2             0             1          0
# 2   335982       2     0     3             0             0          0
# 3   335982       2     0     4             1             1          0
# 4   335982       2     0     5             1             1          0
# 5   335982       2     0     6             0             0          0
# 6   335982       2     0     7             0             0          0
# 7   335982       2     1     1             0             0          1
# 8   335982       2     1     2             0             0          0
# 9   335982       2     1     3             0             4          0
# 10  335982       2     1     4             1             1          0
# 11  335982       2     1     5             0             0          0
# ...

# %%
# crr=run/over

# %%
crr=(ball["runs"]*6)/(120-ball["balls_left"])
ball["crr"]=crr
ball
# Out:
#             id  inning  over  ball  batsman_runs  total_runs_x  is_wicket  \
# 0       335982       2     0     1             1             1          0
# 1       335982       2     0     2             0             1          0
# 2       335982       2     0     3             0             0          0
# 3       335982       2     0     4             1             1          0
# 4       335982       2     0     5             1             1          0
# ...        ...     ...   ...   ...           ...           ...        ...
# 93272  1237181       2    17     6             1             1          0
# 93273  1237181       2    18     1             1             1          0
# 93274  1237181       2    18     2             1             1          0
# 93275  1237181       2    18     3             0             0          1
# 93276  1237181       2    18     4             1             1          0
#
#                       batting_team           bowling_team  total_runs_y  \
# ...

# %%
ball["rrr"]=(ball["runs_left"]*6)/ball["balls_left"]
ball
# Out:
#             id  inning  over  ball  batsman_runs  total_runs_x  is_wicket  \
# 0       335982       2     0     1             1             1          0
# 1       335982       2     0     2             0             1          0
# 2       335982       2     0     3             0             0          0
# 3       335982       2     0     4             1             1          0
# 4       335982       2     0     5             1             1          0
# ...        ...     ...   ...   ...           ...           ...        ...
# 93272  1237181       2    17     6             1             1          0
# 93273  1237181       2    18     1             1             1          0
# 93274  1237181       2    18     2             1             1          0
# 93275  1237181       2    18     3             0             0          1
# 93276  1237181       2    18     4             1             1          0
#
#                       batting_team           bowling_team  total_runs_y  \
# ...

# %%
ball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93277 entries, 0 to 93276
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            93277 non-null  int64
#  1   inning        93277 non-null  int64
#  2   over          93277 non-null  int64
#  3   ball          93277 non-null  int64
#  4   batsman_runs  93277 non-null  int64
#  5   total_runs_x  93277 non-null  int64
#  6   is_wicket     93277 non-null  int64
#  7   batting_team  93277 non-null  object
#  8   bowling_team  93277 non-null  object
#  9   total_runs_y  93277 non-null  int64
#  10  balls_left    93277 non-null  int64
#  11  current_runs  93277 non-null  int64
#  12  wicket_left   93277 non-null  int64
#  13  runs          93277 non-null  int64
#  14  runs_left     93277 non-null  int64
#  15  crr           93277 non-null  float64
#  16  rrr           93271 non-null  float64
# dtypes: float64(2), int64(13), object(2)
# ...

# %%
ball["batting_team"].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Kolkata Knight Riders', 'Rajasthan Royals',
#        'Mumbai Indians', 'Chennai Super Kings', 'Deccan Chargers',
#        'Pune Warriors', 'Kochi Tuskers Kerala', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals'], dtype=object)

# %%
ball["bowling_team"].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Mumbai Indians', 'Deccan Chargers', 'Kings XI Punjab',
#        'Royal Challengers Bangalore', 'Delhi Daredevils',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals'], dtype=object)

# %%
team=[
    'Royal Challengers Bangalore',
    'Kings XI Punjab',
    'Mumbai Indians',
    'Kolkata Knight Riders',
    'Rajasthan Royals',
    'Chennai Super Kings',
    'Sunrisers Hyderabad',
    'Delhi Capitals'
]

# %%
ball["batting_team"]=ball["batting_team"].str.replace('Delhi Daredevils','Delhi Capitals')
ball["bowling_team"]=ball["bowling_team"].str.replace('Delhi Daredevils','Delhi Capitals')

ball["batting_team"]=ball["batting_team"].str.replace('Deccan Chargers','Sunrisers Hyderabad')
ball["bowling_team"]=ball["bowling_team"].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
ball=ball[ball["batting_team"].isin(team)]
ball=ball[ball["bowling_team"].isin(team)]

# %%
ball["bowling_team"].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Mumbai Indians', 'Sunrisers Hyderabad', 'Kings XI Punjab',
#        'Royal Challengers Bangalore', 'Delhi Capitals'], dtype=object)

# %%
ball["batting_team"].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab', 'Delhi Capitals',
#        'Kolkata Knight Riders', 'Rajasthan Royals', 'Mumbai Indians',
#        'Chennai Super Kings', 'Sunrisers Hyderabad'], dtype=object)

# %%
match
# Out:
#           id        city                       winner
# 0     335982   Bangalore        Kolkata Knight Riders
# 1     335983  Chandigarh          Chennai Super Kings
# 2     335984       Delhi             Delhi Daredevils
# 3     335985      Mumbai  Royal Challengers Bangalore
# 4     335986     Kolkata        Kolkata Knight Riders
# ..       ...         ...                          ...
# 811  1216547       Dubai  Royal Challengers Bangalore
# 812  1237177       Dubai               Mumbai Indians
# 813  1237178   Abu Dhabi          Sunrisers Hyderabad
# 814  1237180   Abu Dhabi               Delhi Capitals
# 815  1237181       Dubai               Mumbai Indians
#
# [816 rows x 3 columns]

# %%
match["winner"]=match["winner"].str.replace('Delhi Daredevils','Delhi Capitals')

match["winner"]=match["winner"].str.replace('Deccan Chargers','Sunrisers Hyderabad')


match=match[match["winner"].isin(team)]


match
# Out:
# <ipython-input-41-522ab0a79677>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   match["winner"]=match["winner"].str.replace('Delhi Daredevils','Delhi Capitals')
# <ipython-input-41-522ab0a79677>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   match["winner"]=match["winner"].str.replace('Deccan Chargers','Sunrisers Hyderabad')
#           id        city                       winner
# 0     335982   Bangalore        Kolkata Knight Riders
# ...

# %%
match.isnull().sum()
# Out:
# id         0
# city      13
# winner     0
# dtype: int64

# %%
match=pd.merge(match,ball,how='right',on="id")
match.head(20)
# Out:
#         id       city                 winner  inning  over  ball  \
# 0   335982  Bangalore  Kolkata Knight Riders       2     0     1
# 1   335982  Bangalore  Kolkata Knight Riders       2     0     2
# 2   335982  Bangalore  Kolkata Knight Riders       2     0     3
# 3   335982  Bangalore  Kolkata Knight Riders       2     0     4
# 4   335982  Bangalore  Kolkata Knight Riders       2     0     5
# 5   335982  Bangalore  Kolkata Knight Riders       2     0     6
# 6   335982  Bangalore  Kolkata Knight Riders       2     0     7
# 7   335982  Bangalore  Kolkata Knight Riders       2     1     1
# 8   335982  Bangalore  Kolkata Knight Riders       2     1     2
# 9   335982  Bangalore  Kolkata Knight Riders       2     1     3
# 10  335982  Bangalore  Kolkata Knight Riders       2     1     4
# 11  335982  Bangalore  Kolkata Knight Riders       2     1     5
# 12  335982  Bangalore  Kolkata Knight Riders       2     1     6
# ...

# %%
match.isnull().sum()
# Out:
# id                 0
# city            1554
# winner            27
# inning             0
# over               0
# ball               0
# batsman_runs       0
# total_runs_x       0
# is_wicket          0
# batting_team       0
# bowling_team       0
# total_runs_y       0
# balls_left         0
# current_runs       0
# wicket_left        0
# runs               0
# runs_left          0
# crr                0
# rrr                6
# dtype: int64

# %%
def result(row):
    return 1 if row["batting_team"]==row["winner"] else 0

# %%
match.apply(result,axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 80336    1
# 80337    1
# 80338    1
# 80339    1
# 80340    1
# Length: 80341, dtype: int64

# %%
match["winner"]=match.apply(result,axis=1)
match
# Out:
#             id       city  winner  inning  over  ball  batsman_runs  \
# 0       335982  Bangalore       0       2     0     1             1
# 1       335982  Bangalore       0       2     0     2             0
# 2       335982  Bangalore       0       2     0     3             0
# 3       335982  Bangalore       0       2     0     4             1
# 4       335982  Bangalore       0       2     0     5             1
# ...        ...        ...     ...     ...   ...   ...           ...
# 80336  1237181      Dubai       1       2    17     6             1
# 80337  1237181      Dubai       1       2    18     1             1
# 80338  1237181      Dubai       1       2    18     2             1
# 80339  1237181      Dubai       1       2    18     3             0
# 80340  1237181      Dubai       1       2    18     4             1
#
#        total_runs_x  is_wicket                 batting_team  \
# 0                 1          0  Royal Challengers Bangalore
# ...

# %%
match.isnull().sum()
# Out:
# id                 0
# city            1554
# winner             0
# inning             0
# over               0
# ball               0
# batsman_runs       0
# total_runs_x       0
# is_wicket          0
# batting_team       0
# bowling_team       0
# total_runs_y       0
# balls_left         0
# current_runs       0
# wicket_left        0
# runs               0
# runs_left          0
# crr                0
# rrr                6
# dtype: int64

# %%
final_match=match[['batting_team','bowling_team','city','balls_left','total_runs_y','wicket_left','runs_left','crr','rrr','winner']]
final_match
# Out:
#                       batting_team           bowling_team       city  \
# 0      Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 1      Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 2      Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 3      Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 4      Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# ...                            ...                    ...        ...
# 80336               Mumbai Indians         Delhi Capitals      Dubai
# 80337               Mumbai Indians         Delhi Capitals      Dubai
# 80338               Mumbai Indians         Delhi Capitals      Dubai
# 80339               Mumbai Indians         Delhi Capitals      Dubai
# 80340               Mumbai Indians         Delhi Capitals      Dubai
#
#        balls_left  total_runs_y  wicket_left  runs_left       crr        rrr  \
# ...

# %%
#####################################################################################

# %%
final_match=final_match.sample(final_match.shape[0])

# %%
final_match.isnull().sum()
# Out:
# batting_team       0
# bowling_team       0
# city            1554
# balls_left         0
# total_runs_y       0
# wicket_left        0
# runs_left          0
# crr                0
# rrr                6
# winner             0
# dtype: int64

# %%
final_match.dropna(inplace=True)

# %%
final_match=final_match[final_match["balls_left"]!=0]

# %%
final_match.sample()
# Out:
#          batting_team     bowling_team       city  balls_left  total_runs_y  \
# 10907  Mumbai Indians  Kings XI Punjab  Centurion          57           119
#
#        wicket_left  runs_left       crr       rrr  winner
# 10907            8         44  7.238095  4.631579       1

# %%
X=final_match.iloc[:,:-1]
y=final_match.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#                       batting_team                 bowling_team        city  \
# 68315        Kolkata Knight Riders  Royal Challengers Bangalore   Bengaluru
# 12042        Kolkata Knight Riders          Chennai Super Kings   Centurion
# 73502              Kings XI Punjab               Delhi Capitals       Dubai
# 51379  Royal Challengers Bangalore              Kings XI Punjab  Chandigarh
# 21932              Kings XI Punjab               Delhi Capitals       Delhi
# ...                            ...                          ...         ...
# 46000        Kolkata Knight Riders               Mumbai Indians     Kolkata
# 72555  Royal Challengers Bangalore          Sunrisers Hyderabad   Bengaluru
# 42006  Royal Challengers Bangalore               Mumbai Indians      Mumbai
# 37931             Rajasthan Royals               Mumbai Indians      Mumbai
# 56169  Royal Challengers Bangalore          Sunrisers Hyderabad   Hyderabad
#
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression

from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred=pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8066220948742439

# %%
pipe.predict_proba(X_test)[10]
# Out:
# array([0.18605858, 0.81394142])

# %%
team
# Out:
# ['Royal Challengers Bangalore',
#  'Kings XI Punjab',
#  'Mumbai Indians',
#  'Kolkata Knight Riders',
#  'Rajasthan Royals',
#  'Chennai Super Kings',
#  'Sunrisers Hyderabad',
#  'Delhi Capitals']

# %%
match['city'].unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi', 'Abu Dhabi', nan,
#        'Bengaluru', 'Indore', 'Dubai', 'Sharjah'], dtype=object)

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))
